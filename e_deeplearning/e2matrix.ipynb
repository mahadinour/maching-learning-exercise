# %%
import numpy as np

# %%
revenue = np.array([[180, 200, 220],
                     [24, 36, 40],
                     [12, 18, 20]])

# %%
expenses = np.array([[80, 90, 100],
                     [10, 16, 20],
                     [8,10,10]])

# %% [markdown]
# #matrix substraction

# %%
profite =revenue-expenses

# %%
profite
# Out:
# array([[100, 110, 120],
#        [ 14,  20,  20],
#        [  4,   8,  10]])

# %%
unite = np.array([[1,3,4],
                  [4,56,8],
                  [67,23,90]])

# %%
cost = revenue*unite

# %%
cost
# Out:
# array([[ 180,  600,  880],
#        [  96, 2016,  320],
#        [ 804,  414, 1800]])

# %%
unite2 = np.array([56, 45, 89])

# %%
cost2 = revenue* unite2

# %%
cost2
# Out:
# array([[10080,  9000, 19580],
#        [ 1344,  1620,  3560],
#        [  672,   810,  1780]])

# %%
np.dot(unite , revenue)
# Out:
# array([[  300,   380,   420],
#        [ 2160,  2960,  3280],
#        [13692, 15848, 17460]])
