# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('international_matches.csv')
df
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 25728  2022-06-14         Moldova       Andorra              Europe
# 25729  2022-06-14   Liechtenstein        Latvia              Europe
# 25730  2022-06-14           Chile         Ghana       South America
# 25731  2022-06-14           Japan       Tunisia                Asia
# 25732  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
df = pd.read_csv('international_matches.csv', parse_dates=["date"])
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.describe()
# Out:
#           home_team     away_team  home_team_continent  away_team_continent  \
# count  25733.000000  25733.000000         25733.000000         25733.000000
# mean     107.438853    107.304939             1.700152             1.731395
# std       59.852302     59.977208             1.416498             1.484458
# min        0.000000      0.000000             0.000000             0.000000
# 25%       59.000000     57.000000             1.000000             0.000000
# 50%      104.000000    105.000000             2.000000             2.000000
# 75%      157.000000    157.000000             2.000000             2.000000
# max      210.000000    210.000000             5.000000             5.000000
#
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# count         25733.000000         25733.000000                 25733.000000
# mean             76.937823            79.614464                   300.629037
# ...

# %%
df
# Out:
#             date       home_team     away_team home_team_continent  \
# 0     1993-08-08         Bolivia       Uruguay       South America
# 1     1993-08-08          Brazil        Mexico       South America
# 2     1993-08-08         Ecuador     Venezuela       South America
# 3     1993-08-08          Guinea  Sierra Leone              Africa
# 4     1993-08-08        Paraguay     Argentina       South America
# ...          ...             ...           ...                 ...
# 25728 2022-06-14         Moldova       Andorra              Europe
# 25729 2022-06-14   Liechtenstein        Latvia              Europe
# 25730 2022-06-14           Chile         Ghana       South America
# 25731 2022-06-14           Japan       Tunisia                Asia
# 25732 2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_home_team = LabelEncoder()
le_away_team = LabelEncoder()

le_home_team_continent = LabelEncoder()
le_away_team_continent = LabelEncoder()

le_home_team_result = LabelEncoder()

le_tournament = LabelEncoder()
le_city = LabelEncoder()
le_country = LabelEncoder()
le_neutral_location = LabelEncoder()
le_shoot_out = LabelEncoder()
le_home_team_result = LabelEncoder()

# %%
df['home_team']=le_home_team.fit_transform(df['home_team'])
df['away_team']=le_home_team.fit_transform(df['away_team'])
df['away_team_continent']=le_home_team.fit_transform(df['away_team_continent'])
df['home_team_continent']=le_home_team.fit_transform(df['home_team_continent'])
df['home_team_result']=le_home_team.fit_transform(df['home_team_result'])
df['tournament']=le_home_team.fit_transform(df['tournament'])
df['city']=le_home_team.fit_transform(df['city'])
df['country']=le_home_team.fit_transform(df['country'])
df['neutral_location']=le_home_team.fit_transform(df['neutral_location'])
df['shoot_out']=le_home_team.fit_transform(df['shoot_out'])
df['home_team_result']=le_home_team.fit_transform(df['home_team_result'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25733 entries, 0 to 25732
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           25733 non-null  datetime64[ns]
#  1   home_team                      25733 non-null  int32
#  2   away_team                      25733 non-null  int32
#  3   home_team_continent            25733 non-null  int32
#  4   away_team_continent            25733 non-null  int32
#  5   home_team_fifa_rank            25733 non-null  int64
#  6   away_team_fifa_rank            25733 non-null  int64
#  7   home_team_total_fifa_points    25733 non-null  int64
#  8   away_team_total_fifa_points    25733 non-null  int64
#  9   home_team_score                25733 non-null  int64
#  10  away_team_score                25733 non-null  int64
#  11  tournament                     25733 non-null  int32
# ...

# %%
df=df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25733 entries, 0 to 25732
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           25733 non-null  datetime64[ns]
#  1   home_team                      25733 non-null  int32
#  2   away_team                      25733 non-null  int32
#  3   home_team_continent            25733 non-null  int32
#  4   away_team_continent            25733 non-null  int32
#  5   home_team_fifa_rank            25733 non-null  int64
#  6   away_team_fifa_rank            25733 non-null  int64
#  7   home_team_total_fifa_points    25733 non-null  int64
#  8   away_team_total_fifa_points    25733 non-null  int64
#  9   home_team_score                25733 non-null  int64
#  10  away_team_score                25733 non-null  int64
#  11  tournament                     25733 non-null  int32
# ...

# %%
plt.plot(df['date'], df['home_team_result'])

# %%
df.describe()
# Out:
#           home_team     away_team  home_team_continent  away_team_continent  \
# count  25733.000000  25733.000000         25733.000000         25733.000000
# mean     107.438853    107.304939             1.700152             1.731395
# std       59.852302     59.977208             1.416498             1.484458
# min        0.000000      0.000000             0.000000             0.000000
# 25%       59.000000     57.000000             1.000000             0.000000
# 50%      104.000000    105.000000             2.000000             2.000000
# 75%      157.000000    157.000000             2.000000             2.000000
# max      210.000000    210.000000             5.000000             5.000000
#
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# count         25733.000000         25733.000000                 25733.000000
# mean             76.937823            79.614464                   300.629037
# ...
